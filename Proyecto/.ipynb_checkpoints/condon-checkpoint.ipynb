# %%
import pandas as pd
import random as rm
import numpy as np

import matplotlib.pyplot as plt
from scipy.stats import truncnorm

# %% [markdown]
# ## Cambiamos el nombre de las columnas por nombres que sean mas accesibles

# %%
df_con = pd.read_csv("ventas_condones.csv");
df_con.columns = ['year', 'country', 'sales',
       'revenue', 'campaigns',
       'awareness', 'type',
       'contraceptive_rate', 'teen_pregnancy',
       'hiv_prevention', 'online_sales',
       'price', 'male_female',
       'dominance', 'sex_ducation']

# %%
df_con.head(10)
# Out:
#    year country  sales      revenue campaigns  awareness        type  \
# 0  2015     USA    378   276.304977        No       2.93       Latex
# 1  2015     USA   1875  3002.379846        No       9.28  Ultra-Thin
# 2  2015     USA   2496  6564.222333       Yes       5.26   Non-Latex
# 3  2015     USA   1437  4993.892125       Yes       3.63   Non-Latex
# 4  2015     USA   1923  5355.152313       Yes       5.71   Non-Latex
# 5  2015   India   1273  4200.754788        No       9.48   Non-Latex
# 6  2015   India   1580  4856.165906        No       9.31  Ultra-Thin
# 7  2015   India    116   103.446367        No       3.15   Non-Latex
# 8  2015   India   1774  5508.894147       Yes       9.09   Non-Latex
# 9  2015   India    127   201.716851       Yes       4.79   Non-Latex
#
#    contraceptive_rate  teen_pregnancy  hiv_prevention  online_sales  price  \
# 0               27.10           58.37           89.17         45.00   1.34
# 1               63.97           50.63           69.25         57.10   2.43
# 2               56.21           42.23           56.13         59.52   2.30
# 3               89.71           55.86           78.36         56.83   2.48
# 4               86.96            7.82           37.61         47.99   0.34
# 5               69.16           56.18           60.86          5.07   1.52
# 6               40.95           34.12           90.31         23.89   2.31
# 7               17.97           43.23           54.99         61.79   1.33
# 8               94.18           67.43           79.34         11.33   1.28
# 9               27.39           69.19           59.64         17.67   1.15
#
#              male_female  dominance sex_ducation
# 0  69% Male - 39% Female  Kamasutra           No
# 1  50% Male - 33% Female       Skyn           No
# 2  46% Male - 54% Female       Skyn          Yes
# 3  49% Male - 57% Female   Manforce           No
# 4  40% Male - 29% Female     Trojan          Yes
# 5  73% Male - 48% Female  Kamasutra           No
# 6  42% Male - 44% Female       Skyn          Yes
# 7  58% Male - 29% Female       Skyn           No
# 8  72% Male - 28% Female     Trojan          Yes
# 9  48% Male - 57% Female     Trojan          Yes

# %% [markdown]
# ## Eliminamos las columnas que no vamos a utilizar

# %%
df_con = df_con.drop(columns = ['male_female'])

# %% [markdown]
# ## Creamos funciones para obtener las columnas numericas y cartegoricas

# %%
def getInt(df):
    col_number = [];
    for column in df:
        if(df[column].dtype != 'O'):
            col_number.append(column)
    return col_number

def getCat(df):
    col_cat = [];
    for column in df:
        if(df[column].dtype == 'O'):
            col_cat.append(column)
    return col_cat

# %%
col_num = getInt(df_con)
col_cat = getCat(df_con)

# %%
df_con.boxplot(column='revenue', by='type', figsize=(10, 6), rot=45)
plt.title('Distribucion de precios segun el tipo')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %%
df_con[col_num].describe()
# Out:
#               year        sales      revenue   awareness  contraceptive_rate  \
# count   550.000000   550.000000   550.000000  550.000000          550.000000
# mean   2020.000000  1217.850909  2460.104428    6.248382           54.625527
# std       3.165156   707.861532  1908.028885    2.393678           22.865826
# min    2015.000000    51.000000    34.656206    2.010000           15.020000
# 25%    2017.000000   599.750000   947.550178    4.065000           34.775000
# 50%    2020.000000  1160.000000  2002.374241    6.435000           53.920000
# 75%    2023.000000  1846.000000  3593.351620    8.432500           75.747500
# max    2025.000000  2500.000000  8536.163259    9.980000           94.970000
#
#        teen_pregnancy  hiv_prevention  online_sales       price
# count      550.000000      550.000000    550.000000  550.000000
# mean        34.780055       62.049836     36.902309    1.360891
# std         19.778428       21.341931     19.256040    0.664664
# min          2.020000       25.070000      5.010000    0.200000
# 25%         17.532500       43.860000     19.565000    0.782500
# 50%         34.705000       63.125000     35.505000    1.390000
# 75%         50.787500       79.990000     52.917500    1.927500
# max         69.890000       98.840000     69.960000    2.490000

# %% [markdown]
# ## Eliminamos valores atipicos

# %%
def getValuesQR(columns, df):
    dic_qr = { "columns" : [], "atp_sup" : [], "atp_inf" : []}
    for column in columns: 
        data = df[column].to_list()
        data_serie = pd.Series(data)

        Q1 = data_serie.quantile(0.25)
        Q3 = data_serie.quantile(0.75)

        IQR = Q3 - Q1

        upper_bound = Q3 + 1.5 * IQR
        lower_bound = Q1 - 1.5 * IQR

        atp_sup = df[column].loc[df[column] > upper_bound].count()
        atp_inf = df[column].loc[df[column] < lower_bound].count()
        
        dic_qr["columns"].append(column)
        dic_qr["atp_sup"].append(atp_sup)
        dic_qr["atp_inf"].append(atp_inf)

    return dic_qr

# %%
pd_con_out = pd.DataFrame(getValuesQR(col_num, df_con))
pd_con_out
# Out:
#               columns  atp_sup  atp_inf
# 0                year        0        0
# 1               sales        0        0
# 2             revenue        8        0
# 3           awareness        0        0
# 4  contraceptive_rate        0        0
# 5      teen_pregnancy        0        0
# 6      hiv_prevention        0        0
# 7        online_sales        0        0
# 8               price        0        0

# %% [markdown]
# ## Obtenemos las probabilidades categoricas

# %%
def getProb(cats, df):
    prob_index = {}
    index = 0
    for cat in cats:
        array_prob = [[],[]]
        vals = df_con[cat].drop_duplicates().to_list()
        for val in vals:
            array_prob[0].append(val)
            array_prob[1].append(df_con[cat].loc[df_con[cat] == val].count()/df_con[cat].count())
        prob_index[cat] = array_prob
    return prob_index

# %%
probs = getProb(col_cat, df_con)
probs
# Out:
# {'country': [['USA',
#    'India',
#    'UK',
#    'Brazil',
#    'Germany',
#    'South Africa',
#    'China',
#    'Japan',
#    'France',
#    'Australia'],
#   [np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1),
#    np.float64(0.1)]],
#  'campaigns': [['No', 'Yes'],
#   [np.float64(0.5254545454545455), np.float64(0.47454545454545455)]],
#  'type': [['Latex', 'Ultra-Thin', 'Non-Latex', 'Textured'],
#   [np.float64(0.2290909090909091),
#    np.float64(0.2545454545454545),
#    np.float64(0.2290909090909091),
#    np.float64(0.2872727272727273)]],
#  'dominance': [['Kamasutra',
#    'Skyn',
#    'Manforce',
#    'Trojan',
#    'LifeStyles',
#    'Durex',
#    'Okamoto'],
#   [np.float64(0.15454545454545454),
#    np.float64(0.13090909090909092),
#    np.float64(0.1690909090909091),
#    np.float64(0.14181818181818182),
#    np.float64(0.12363636363636364),
#    np.float64(0.13818181818181818),
#    np.float64(0.14181818181818182)]],
#  'sex_ducation': [['No', 'Yes'],
#   [np.float64(0.5072727272727273), np.float64(0.49272727272727274)]]}

# %% [markdown]
# ## Obtenemos los valores maximos, minimos, media, mediana... de los valores numericos

# %%
def getDic(columns, df):
    dic = {}
    for column in columns:
        dic[column] = {}
        dic[column]["min"] = df[column].min()
        dic[column]["max"] = df[column].max()
        dic[column]["mean"] = df[column].mean()
        dic[column]["std"] = df[column].std()
    return dic

# %%
pd_tp = pd_con_out.sort_values(by="atp_sup", ascending=False)
dic_tp = getDic(pd_tp["columns"].to_list(), df_con)
dic_tp
# Out:
# {'revenue': {'min': np.float64(34.65620552035023),
#   'max': np.float64(8536.163259488441),
#   'mean': np.float64(2460.104428197126),
#   'std': np.float64(1908.028884948079)},
#  'year': {'min': np.int64(2015),
#   'max': np.int64(2025),
#   'mean': np.float64(2020.0),
#   'std': np.float64(3.165156384169307)},
#  'sales': {'min': np.int64(51),
#   'max': np.int64(2500),
#   'mean': np.float64(1217.850909090909),
#   'std': np.float64(707.861532072138)},
#  'awareness': {'min': np.float64(2.01),
#   'max': np.float64(9.98),
#   'mean': np.float64(6.2483818181818185),
#   'std': np.float64(2.3936781719616462)},
#  'contraceptive_rate': {'min': np.float64(15.02),
#   'max': np.float64(94.97),
#   'mean': np.float64(54.625527272727275),
#   'std': np.float64(22.865826228285943)},
#  'teen_pregnancy': {'min': np.float64(2.02),
#   'max': np.float64(69.89),
#   'mean': np.float64(34.78005454545454),
#   'std': np.float64(19.77842825461327)},
#  'hiv_prevention': {'min': np.float64(25.07),
#   'max': np.float64(98.84),
#   'mean': np.float64(62.04983636363636),
#   'std': np.float64(21.341931433536978)},
#  'online_sales': {'min': np.float64(5.01),
#   'max': np.float64(69.96),
#   'mean': np.float64(36.90230909090909),
#   'std': np.float64(19.256039696310655)},
#  'price': {'min': np.float64(0.2),
#   'max': np.float64(2.49),
#   'mean': np.float64(1.3608909090909092),
#   'std': np.float64(0.6646637445805419)}}

# %% [markdown]
# ## Crea las columnas a simular

# %%
def returnDic_num (registrosSimular, df, size):
    d_r = {}
    for key in registrosSimular.keys():

        min_val = registrosSimular[key]["min"]
        max_val = registrosSimular[key]["max"]
        
        if key == 'year':
            values = [rm.randint(min_val, max_val) for _ in range(size)]
        else:
            media = registrosSimular[key]["mean"]
            desv_std = registrosSimular[key]["std"]
    
            a, b = (min_val - media) / desv_std, (max_val - media) / desv_std
    
            values = truncnorm.rvs(a, b, media, desv_std, size)
        
        d_r[key] = values

    return d_r

def returnDic_cat (registrosSimular, size):
    d_r = {}
    for key in registrosSimular.keys():

        d_r[key] = np.random.choice(registrosSimular[key][0], size, registrosSimular[key][0])

    return d_r

# %%
size = 100000

registrosSimular_cat = probs
simulacion_cat = returnDic_cat(registrosSimular_cat, size);

registrosSimular_num = dic_tp2
simulacion_num = returnDic_num(registrosSimular, df_con, size)

simulacion_cat.update(simulacion_num)

# %%
simulacion = pd.DataFrame(simulacion_cat)

# %% [markdown]
# ## Comparacion de datos numericos

# %%
simulacion.describe()
# Out:
#              revenue           year          sales      awareness  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean     2829.298274    2019.993360    1235.111931       6.166218
# std      1597.441082       3.163646     575.522703       1.902941
# min        34.853624    2015.000000      51.044658       2.010108
# 25%      1591.664970    2017.000000     798.896332       4.754288
# 50%      2706.101144    2020.000000    1228.624936       6.204908
# 75%      3901.201724    2023.000000    1662.660461       7.628957
# max      8526.626260    2025.000000    2499.929442       9.979929
#
#        contraceptive_rate  teen_pregnancy  hiv_prevention   online_sales  \
# count       100000.000000   100000.000000   100000.000000  100000.000000
# mean            54.731423       35.284878       61.972062      37.118315
# std             18.671546       16.009278       17.396606      15.413896
# min             15.022732        2.025321       25.074040       5.014739
# 25%             40.755157       23.281950       48.932062      25.443992
# 50%             54.653190       35.058316       61.950316      36.998838
# 75%             68.603875       47.251899       74.964261      48.707299
# max             94.968589       69.888577       98.839095      69.957880
#
#                price
# count  100000.000000
# mean        1.356122
# std         0.539317
# min         0.200067
# 25%         0.951738
# 50%         1.358845
# 75%         1.760033
# max         2.489986

# %%
df_con.describe()
# Out:
#               year        sales      revenue   awareness  contraceptive_rate  \
# count   550.000000   550.000000   550.000000  550.000000          550.000000
# mean   2020.000000  1217.850909  2460.104428    6.248382           54.625527
# std       3.165156   707.861532  1908.028885    2.393678           22.865826
# min    2015.000000    51.000000    34.656206    2.010000           15.020000
# 25%    2017.000000   599.750000   947.550178    4.065000           34.775000
# 50%    2020.000000  1160.000000  2002.374241    6.435000           53.920000
# 75%    2023.000000  1846.000000  3593.351620    8.432500           75.747500
# max    2025.000000  2500.000000  8536.163259    9.980000           94.970000
#
#        teen_pregnancy  hiv_prevention  online_sales       price
# count      550.000000      550.000000    550.000000  550.000000
# mean        34.780055       62.049836     36.902309    1.360891
# std         19.778428       21.341931     19.256040    0.664664
# min          2.020000       25.070000      5.010000    0.200000
# 25%         17.532500       43.860000     19.565000    0.782500
# 50%         34.705000       63.125000     35.505000    1.390000
# 75%         50.787500       79.990000     52.917500    1.927500
# max         69.890000       98.840000     69.960000    2.490000
